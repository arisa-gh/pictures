# %% [markdown]
# <a href="https://colab.research.google.com/github/arisa-gh/pictures/blob/master/learning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import sys
sys.path.append('/content/drive/My Drive/pictures/')

import importlib
import ic_module as ic
importlib.reload(ic)

# 関数実行
ic.Learning(tsnum=30, nb_epoch=50, batch_size=8, learn_schedule=0.9)
# Out:
# >> 学習サンプル数 :  (432, 32, 32, 3)
# >> 学習開始
# Epoch 1/50
# 43/43 [==============================] - ETA: 0s - loss: 1.1190 - accuracy: 0.3333
# Epoch 00001: val_loss improved from inf to 1.09875, saving model to best.hdf5
# 43/43 [==============================] - 2s 57ms/step - loss: 1.1190 - accuracy: 0.3333 - val_loss: 1.0987 - val_accuracy: 0.2889
# Epoch 2/50
# 42/43 [============================>.] - ETA: 0s - loss: 1.0995 - accuracy: 0.3631
# Epoch 00002: val_loss improved from 1.09875 to 1.09766, saving model to best.hdf5
# 43/43 [==============================] - 2s 53ms/step - loss: 1.0993 - accuracy: 0.3626 - val_loss: 1.0977 - val_accuracy: 0.3333
# Epoch 3/50
# 42/43 [============================>.] - ETA: 0s - loss: 1.0934 - accuracy: 0.3988
# Epoch 00003: val_loss improved from 1.09766 to 1.09656, saving model to best.hdf5
# 43/43 [==============================] - 2s 53ms/step - loss: 1.0941 - accuracy: 0.3947 - val_loss: 1.0966 - val_accuracy: 0.3556
# Epoch 4/50
# 42/43 [============================>.] - ETA: 0s - loss: 1.0858 - accuracy: 0.4107
# Epoch 00004: val_loss did not improve from 1.09656
# 43/43 [==============================] - 2s 52ms/step - loss: 1.0854 - accuracy: 0.4094 - val_loss: 1.0979 - val_accuracy: 0.3778
# Epoch 5/50
# 43/43 [==============================] - ETA: 0s - loss: 1.0438 - accuracy: 0.4971
# Epoch 00005: val_loss improved from 1.09656 to 1.07982, saving model to best.hdf5
# 43/43 [==============================] - 2s 54ms/step - loss: 1.0438 - accuracy: 0.4971 - val_loss: 1.0798 - val_accuracy: 0.4778
# Epoch 6/50
# 43/43 [==============================] - ETA: 0s - loss: 1.0071 - accuracy: 0.5088
# Epoch 00006: val_loss did not improve from 1.07982
# 43/43 [==============================] - 2s 52ms/step - loss: 1.0071 - accuracy: 0.5088 - val_loss: 1.1748 - val_accuracy: 0.4778
# Epoch 7/50
# 42/43 [============================>.] - ETA: 0s - loss: 0.9515 - accuracy: 0.5595
# Epoch 00007: val_loss did not improve from 1.07982
# 43/43 [==============================] - 2s 53ms/step - loss: 0.9525 - accuracy: 0.5585 - val_loss: 1.1801 - val_accuracy: 0.4111
# Epoch 8/50
# 42/43 [============================>.] - ETA: 0s - loss: 0.9072 - accuracy: 0.6339
# Epoch 00008: val_loss did not improve from 1.07982
# 43/43 [==============================] - 2s 52ms/step - loss: 0.9108 - accuracy: 0.6287 - val_loss: 1.1702 - val_accuracy: 0.4889
# Epoch 9/50
# 43/43 [==============================] - ETA: 0s - loss: 0.8712 - accuracy: 0.6199
# Epoch 00009: val_loss did not improve from 1.07982
# 43/43 [==============================] - 2s 52ms/step - loss: 0.8712 - accuracy: 0.6199 - val_loss: 1.2181 - val_accuracy: 0.3889
# Epoch 10/50
# 42/43 [============================>.] - ETA: 0s - loss: 0.8546 - accuracy: 0.6250
# Epoch 00010: val_loss did not improve from 1.07982
# 43/43 [==============================] - 2s 54ms/step - loss: 0.8606 - accuracy: 0.6228 - val_loss: 1.3024 - val_accuracy: 0.4000
# Epoch 11/50
# 43/43 [==============================] - ETA: 0s - loss: 0.8285 - accuracy: 0.6257
# Epoch 00011: val_loss did not improve from 1.07982
# 43/43 [==============================] - 2s
val_loss did not improve from 1.07982
# 43/43 [==============================] - 2s 53ms/step - loss: 0.4480 - accuracy: 0.8275 - val_loss: 1.6963 - val_accuracy: 0.4667
# Epoch 39/50
# 43/43 [==============================] - ETA: 0s - loss: 0.4428 - accuracy: 0.8187
# Epoch 00039: val_loss did not improve from 1.07982
# 43/43 [==============================] - 2s 51ms/step - loss: 0.4428 - accuracy: 0.8187 - val_loss: 1.7036 - val_accuracy: 0.4778
# Epoch 40/50
# 42/43 [============================>.] - ETA: 0s - loss: 0.4336 - accuracy: 0.8304
# Epoch 00040: val_loss did not improve from 1.07982
# 43/43 [==============================] - 2s 52ms/step - loss: 0.4441 - accuracy: 0.8275 - val_loss: 1.7090 - val_accuracy: 0.4667
# Epoch 41/50
# 43/43 [==============================] - ETA: 0s - loss: 0.4349 - accuracy: 0.8538
# Epoch 00041: val_loss did not improve from 1.07982
# 43/43 [==============================] - 2s 52ms/step - loss: 0.4349 - accuracy: 0.8538 - val_loss: 1.7122 - val_accuracy: 0.4667
# Epoch 42/50
# 43/43 [==============================] - ETA: 0s - loss: 0.4271 - accuracy: 0.8509
# Epoch 00042: val_loss did not improve from 1.07982
# 43/43 [==============================] - 2s 53ms/step - loss: 0.4271 - accuracy: 0.8509 - val_loss: 1.7138 - val_accuracy: 0.4667
# Epoch 43/50
# 43/43 [==============================] - ETA: 0s - loss: 0.4389 - accuracy: 0.8363
# Epoch 00043: val_loss did not improve from 1.07982
# 43/43 [==============================] - 2s 54ms/step - loss: 0.4389 - accuracy: 0.8363 - val_loss: 1.7295 - val_accuracy: 0.4667
# Epoch 44/50
# 43/43 [==============================] - ETA: 0s - loss: 0.4364 - accuracy: 0.8363
# Epoch 00044: val_loss did not improve from 1.07982
# 43/43 [==============================] - 2s 53ms/step - loss: 0.4364 - accuracy: 0.8363 - val_loss: 1.7333 - val_accuracy: 0.4667
# Epoch 45/50
# 42/43 [============================>.] - ETA: 0s - loss: 0.4279 - accuracy: 0.8244
# Epoch 00045: val_loss did not improve from 1.07982
# 43/43 [==============================] - 2s 52ms/step - loss: 0.4233 - accuracy: 0.8275 - val_loss: 1.7444 - val_accuracy: 0.4667
# Epoch 46/50
# 42/43 [============================>.] - ETA: 0s - loss: 0.4261 - accuracy: 0.8363
# Epoch 00046: val_loss did not improve from 1.07982
# 43/43 [==============================] - 2s 53ms/step - loss: 0.4243 - accuracy: 0.8392 - val_loss: 1.7487 - val_accuracy: 0.4667
# Epoch 47/50
# 42/43 [============================>.] - ETA: 0s - loss: 0.4359 - accuracy: 0.8304
# Epoch 00047: val_loss did not improve from 1.07982
# 43/43 [==============================] - 2s 54ms/step - loss: 0.4348 - accuracy: 0.8304 - val_loss: 1.7540 - val_accuracy: 0.4667
# Epoch 48/50
# 43/43 [==============================] - ETA: 0s - loss: 0.4494 - accuracy: 0.8304
# Epoch 00048: val_loss did not improve from 1.07982
# 43/43 [==============================] - 2s 54ms/step - loss: 0.4494 - accuracy: 0.8304 - val_loss: 1.7550 - val_accuracy: 0.4667
# Epoch 49/50
# 43/43 [==============================] - ETA: 0s - loss: 0.4457 - accuracy: 0.8333
# Epoch 00049: val_loss did not improve from 1.07982
# 43/43 [==============================] - 2s 52ms/step - loss: 0.4457 - accuracy: 0.8333 - val_loss: 1.7557 - val_accuracy: 0.4667
# Epoch 50/50
# 42/43 [============================>.] - ETA: 0s - loss: 0.4418 - accuracy: 0.8393
# Epoch 00050: val_loss did not improve from 1.07982
# 43/43 [==============================] - 2s 52ms/step - loss: 0.4415 - accuracy: 0.8392 - val_loss: 1.7548 - val_accuracy: 0.4667

# %%
import ic_module as ic
import os.path as op

while True:
    while True:
        imgname = input("\n>> 入力したい画像ファイル(「END」で終了) ： ")
        if op.isfile(imgname) or imgname == "END":
            break
        print(">> そのファイルは存在しません！")
    if imgname == "END":
        break

    # 関数実行
    ic.TestProcess(imgname)
# Out:
# >> 入力したい画像ファイル(「END」で終了) ： /content/drive/My Drive/pictures/face/test
# >> そのファイルは存在しません！
#
# >> 入力したい画像ファイル(「END」で終了) ： test
# >> そのファイルは存在しません！
#
# >> 入力したい画像ファイル(「END」で終了) ： /content/drive/My Drive/pictures/face/test/image_12.jpg
# >> 計算結果↓
# [[0.21805383 0.7625905  0.01935566]]
# >> この画像は「橋本環奈」です。
#
# >> 入力したい画像ファイル(「END」で終了) ： /content/drive/My Drive/pictures/face/test/image_13.jpg
# >> 計算結果↓
# [[0.64599144 0.3427397  0.01126882]]
# >> この画像は「山下美月」です。
#
# >> 入力したい画像ファイル(「END」で終了) ： /content/drive/My Drive/pictures/face/test/image_14.jpg
# >> 計算結果↓
# [[0.219828   0.67991847 0.10025353]]
# >> この画像は「橋本環奈」です。
#
# >> 入力したい画像ファイル(「END」で終了) ： /content/drive/My Drive/pictures/face/test/image_15.jpg
# >> 計算結果↓
# [[0.06837586 0.8501692  0.08145493]]
# >> この画像は「橋本環奈」です。
#
# >> 入力したい画像ファイル(「END」で終了) ： /content/drive/My Drive/pictures/face/test/image_0.jpg
# WARNING:tensorflow:5 out of the last 5 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f0a91e6d730> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# >> 計算結果↓
# [[0.0241129  0.05059047 0.92529666]]
# >> この画像は「白石麻衣」です。
#
# >> 入力したい画像ファイル(「END」で終了) ： /content/drive/My Drive/pictures/face/test/image_1.jpg
# WARNING:tensorflow:6 out of the last 6 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f0a91e6d598> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# >> 計算結果↓
# [[0.01919231 0.0188737  0.96193403]]
# >> この画像は「白石麻衣」です。
#
# >> 入力したい画像ファイル(「END」で終了) ： /content/drive/My Drive/pictures/face/test/image_3.jpg
# WARNING:tensorflow:7 out of the last 7 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f0a91d71400> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# >> 計算結果↓
# [[0.02959906 0.25722054 0.71318036]]
# >> この画像は「白石麻衣」です。
#
# >> 入力したい画像ファイル(「END」で終了) ： /content/drive/My Drive/pictures/face/test/image_2.jpg
# WARNING:tensorflow:8 out of the last 8 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f0a91e0c2f0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# >> 計算結果↓
# [[0.01894059 0.07349488 0.9075645 ]]
# >> この画像は「白石麻衣」です。
#
# >> 入力したい画像ファイル(「END」で終了) ： /content/drive/My Drive/pictures/face/test/image_8.jpg
# WARNING:tensorflow:9 out of the last 9 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f0a91c5a488> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# >> 計算結果↓
# [[0.98883575 0.00841087 0.00275342]]
# >> この画像は「山下美月」です。
#
# >> 入力したい画像ファイル(「END」で終了) ： /content/drive/My Drive/pictures/face/test/image_9.jpg
# WARNING:tensorflow:10 out of the last 10 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f0a91bfe0d0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# >> 計算結果↓
# [[0.9839235  0.01298024 0.00309627]]
# >> この画像は「山下美月」です。
#
# >> 入力したい画像ファイル(「END」で終了) ： /content/drive/My Drive/pictures/face/test/image_10.jpg
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f0a91b43510> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# >> 計算結果↓
# [[0.63770044 0.21297397 0.14932565]]
# >> この画像は「山下美月」です。
#
# >> 入力したい画像ファイル(「END」で終了) ： /content/drive/My Drive/pictures/face/test/image_11.jpg
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f0a91ab6b70> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# >> 計算結果↓
# [[0.42507014 0.43388736 0.14104243]]
# >> この画像は「橋本環奈」です。
